# %%
# !pip install requests
# Out:
# ...
#     100% |████████████████████████████████| 593kB 227kB/s ta 0:00:011�████████████████▌        | 430kB 62.4MB/s eta 0:00:01    87% |████████████████████████████    | 512kB 1.1MB/s eta 0:00:01
# ...

# %%
import requests

def download_file_from_google_drive(id, destination):
    URL = "https://drive.google.com/uc?export=download&id=0B16OiWl7I-fBdmZuZWJ1RGRFcU0"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

if __name__ == "__main__":
    file_id = '0B16OiWl7I-fBdmZuZWJ1RGRFcU0'
    destination = 'train-jpg.zip'
    download_file_from_google_drive(file_id, destination)
    #https://drive.google.com/open?id=0B16OiWl7I-fBdmZuZWJ1RGRFcU0

# %%
# !unzip train-jpg.zip -d data
# Out:
# Archive:  train-jpg.zip
#    creating: data/train-jpg/
#   inflating: data/train-jpg/train_0.jpg
#  extracting: data/train-jpg/train_1.jpg
#   inflating: data/train-jpg/train_10.jpg
#   inflating: data/train-jpg/train_100.jpg
#   inflating: data/train-jpg/train_1000.jpg
#   inflating: data/train-jpg/train_10000.jpg
#   inflating: data/train-jpg/train_10001.jpg
#   inflating: data/train-jpg/train_10002.jpg
#   inflating: data/train-jpg/train_10003.jpg
#   inflating: data/train-jpg/train_10004.jpg
#   inflating: data/train-jpg/train_10005.jpg
#   inflating: data/train-jpg/train_10006.jpg
#   inflating: data/train-jpg/train_10007.jpg
#  extracting: data/train-jpg/train_10008.jpg
#   inflating: data/train-jpg/train_10009.jpg
#   inflating: data/train-jpg/train_1001.jpg
#  extracting: data/train-jpg/train_10010.jpg
#   inflating: data/train-jpg/train_10011.jpg
#   inflating: data/train-jpg/train_10012.jpg
#   inflating: data/train-jpg/train_10013.jpg
# ...

# %%
import requests

def download_file_from_google_drive(id, destination):
    URL = "https://drive.google.com/uc?export=download&id=0B16OiWl7I-fBejNtYnlYaTBqS00"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

if __name__ == "__main__":
    file_id = 'B16OiWl7I-fBejNtYnlYaTBqS00'
    destination = 'weights2.h5'
    download_file_from_google_drive(file_id, destination)
    #https://drive.google.com/file/d/0B16OiWl7I-fBejNtYnlYaTBqS00/view?usp=sharing

# %%
import requests

def download_file_from_google_drive(id, destination):
    URL = "https://drive.google.com/uc?export=download&id=0B16OiWl7I-fBejNtYnlYaTBqS00"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

if __name__ == "__main__":
    file_id = 'B16OiWl7I-fBejNtYnlYaTBqS00'
    destination = 'weights2.h5'
    download_file_from_google_drive(file_id, destination)
    #https://drive.google.com/file/d/0B16OiWl7I-fBejNtYnlYaTBqS00/view?usp=sharing

# %%
import requests

def download_file_from_google_drive(id, destination):
    URL = "https://drive.google.com/uc?export=download&id=0B16OiWl7I-fBejNtYnlYaTBqS00"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

if __name__ == "__main__":
    file_id = 'B16OiWl7I-fBejNtYnlYaTBqS00'
    destination = 'weights2.h5'
    download_file_from_google_drive(file_id, destination)
    #https://drive.google.com/file/d/0B16OiWl7I-fBejNtYnlYaTBqS00/view?usp=sharing
